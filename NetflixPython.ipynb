# %%
import pandas as pd
import seaborn as sns

# %%
ndata = pd.read_csv(r"E:\FF\Data Analysis\SQL\netflix_titles.csv")

# %%
ndata
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#mostrar los top5 registrados en la dataset
ndata.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#mostrar los bottom5 registrados en la dataset
ndata.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
#mostrar el numero de filas y columnas en la dataset
ndata.shape
# Out:
# (8807, 12)

# %%
#mostrar el No. del total de los valores en el dataset
ndata.size
# Out:
# 105684

# %%
#mostrar el nombre de cada columna
ndata.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#mostrar el tipo de data de cada columna
ndata.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#mostrar indexes, columnas, tipo de data, memoria al mismo tiempo
ndata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# Si hay duplicados en el dataset, removerlo
ndata[ndata.duplicated()]
#ndata.drop_duplicates(inplace = True)
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# Si hay algun valor nulo en el dataset, mostrarlo con un Heat-map
#ndata.isnull()
#ndata.isnull().sum()
#sns.heatmap(ndata.isnull())

# %%
#Para 'House of Cards', cual es el Showid y quien es el Director
#ndata[ndata['title'].isin(['House of Cards'])]
ndata[ndata['title'].str.contains('House of Cards')]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
#En cual año se estrenaron el mayor numero de TvShows y peliculas, mostrarlo con una grafica de barras
#ndata['DateN'] = pd.to_datetime(ndata['release_year']) #lo podemos usar en date_added
#ndata['Date_N'] = pd.to_datetime(ndata['release_year'], errors='coerce')
#ndata['release_year'].dt.year.value_counts()
#ndata['DateN'].dt.year.value_counts()

# %%
#En cual año se estrenaron el mayor numero de TvShows y peliculas, mostrarlo con una grafica de barras
#ndata['DateAd'] = pd.to_datetime(ndata['date_added'], format='mixed') #lo podemos usar en date_added
#ndata['DateAd'].dt.year.value_counts()
ndata['DateAd'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='DateAd'>

# %%
#cuantas peliculas y series hay en el dataset, mostrarlo en grafica de barras
#ndata.groupby('type').type.count()
sns.countplot(x=ndata['type'])
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
#mostrar todas las peliculas que se publicaron en el año 2000
#ndata['DateAd'] = pd.to_datetime(ndata['date_added'], errors='coerce')
#ndata['DateAd'] = pd.to_datetime(ndata['release_year'], errors='coerce')
ndata.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#mostrar todas las peliculas que se publicaron en el año 2000
#ndata['yearR'] = pd.to_datetime(ndata['release_year'], format='mixed')
#ndata['year_relase'] = pd.to_datetime(ndata['release_year'],  format='%Y') ESPOR ACA
#ndata['Year'] = ndata['year_relase'].dt.year
ndata[(ndata['type'] == 'Movie') & (ndata['Year'] == 2000)]
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %%
#mostrar solo los titulos de todos las series que son de origen Argentino
ndata[(ndata['type']=='TV Show') & (ndata['country']=='Argentina')] ['title']
# Out:
# 275                          The Kingdom
# 434                               Okupas
# 673                    No Time for Shame
# 709                          Millennials
# 1733     Carmel: Who Killed Maria Marta?
# 1917               Secreto bien guardado
# 2565                        Almost Happy
# 2894                            Puerta 7
# 3375             Monzón: A Knockout Blow
# 3483                         El Marginal
# 3576    Apache: The Life of Carlos Tevez
# 3722                   Go! Live Your Way
# 3823            Heidi, bienvenida a casa
# 4111               The Kirlian Frequency
# 4430                            Creators
# 4978                                Edha
# 6974                 Historia de un clan
# 7800                         Psiconautas
# Name: title, dtype: object

# %%
#Mostrar los TOP 10 directores, que dieron el numero mas alto en peliculas y series a netflix
ndata['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
#Mostrar todos los registros, donde "categoria es pelicula y tipo es comedia" o "pais es United Kingdom"
ndata[((ndata['type']=='Movie') & (ndata['listed_in']=='Comedies')) | (ndata['country'] == 'United Kingdom') ]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
#en cuantas peliculas/series, Tom Cruise fue parte?
ndata[ndata['cast'] == 'Tom Cruise']
#ndata[ndata['cast'].str.contains('Tom Cruise')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, DateAd, year_relase, Year]
# Index: []

# %%
ndata['cast'] = ndata['cast'].astype(str)
ndata[ndata['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description     DateAd  \
# 341   Through chance, history and divine interventio... 2021-08-01
# 1254  Motivated by money, a selfish workaholic seeki... 2021-03-01
#
#      year_relase  Year
# 341   1999-01-01  1999
# 1254  1988-01-01  1988

# %%
#cuales son los diferentes Valores definidos por netflix
ndata['rating'].nunique()
#ndata['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
#cuantas peliculas tienen 'TV-14' como valor en Canada?
#ndata[((ndata['type']=='Movie') & ( ndata['rating']=='TV-14')) & (ndata['country']=='Canada')]
ndata[((ndata['type']=='Movie') & ( ndata['rating']=='TV-14')) & (ndata['country']=='Canada')].shape
# Out:
# (13, 15)

# %%
#Cuantos tvshows tienen la valoracion 'R', despues del año 2018?
ndata[((ndata['type']=='TV Show') & ( ndata['rating']=='R')) & (ndata['Year'] > 2018)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, DateAd, year_relase, Year]
# Index: []

# %%
#cual es la duracion maxima de una pelicula/serie on Netflix?
#df.loc[df['Category'] == 'Movie'].groupby('Category')['Numeric_duration'].max().reset_index()
#ndata[['Minutes','Unit']] = ndata['duration'].str.split(' ',expand = True)
#ndata['Minutes'] = ndata['Minutes'].astype('int')
max(ndata.Minutes.astype('float'))
# Out:
# 312.0

# %%
#encontrar todos los registros donde Categoria es 'Movie' y Type es 'Drama' O Categoria es 'TV Show' y Type es 'Kids' TV'
ndata[((ndata['type']=='Movie') & ( ndata['rating']=='Dramas')) | ((ndata['type']=="TV Show") & ( ndata['rating']=="Kids' TV"))]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, DateAd, year_relase, Year, Minutes, Unit]
# Index: []
